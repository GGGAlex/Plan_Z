# %%
import pandas as pd

import json
csv_file1 = 'tmdb_5000_movies.csv'
csv_file2 = 'movies.csv'

df1 = pd.read_csv(csv_file1)
df2 = pd.read_csv(csv_file2)

df2.rename(columns={'name': 'title'}, inplace=True)
df = pd.merge(df1, df2, on='title')
df.drop(['budget_x','keywords','genres','homepage','id','original_title','rating','gross',\
         'budget_y','spoken_languages','runtime_y','production_companies','revenue',\
         'production_countries','tagline','released','votes','year','status','score',\
         'popularity'], axis=1, inplace=True)
df.rename(columns={'original_language': 'language','runtime_x': 'runtime'}, inplace=True)
# df.rename(columns={'original_language': 'language','runtime_x': 'runtime'}, inplace=True)

#df.set_index('title', inplace=True)
df['release_date'] = df['release_date'].str.replace('-', '')
df['release_date'] = df['release_date'].map(lambda x: int(x)//10000)
movie_of_year = df.groupby('release_date', group_keys=False).apply(lambda x: x.sort_values('vote_average',ascending=False))\
                    .groupby('release_date').head(5)
movie_of_year.drop(['overview', 'writer', 'star', 'runtime', 'company',
                        'genre', 'vote_count'], axis=1, inplace=True)
movie_of_year = movie_of_year[movie_of_year.release_date>2005].reset_index()
movie_of_year.drop(['index'], axis=1, inplace=True)
# movie_of_year = movie_of_year.groupby(by='release_date')
        #topmovie = movie_of_year.to_json()
movie_of_year
# Out:
#    language  release_date                            title  vote_average  \
# 0        en          2006                     The Prestige           8.0
# 1        en          2006                     The Departed           7.9
# 2        de          2006              The Lives of Others           7.9
# 3        en          2006         The Pursuit of Happyness           7.7
# 4        en          2006                   V for Vendetta           7.7
# 5        en          2007              There Will Be Blood           7.9
# 6        en          2007                    Into the Wild           7.8
# 7        pt          2007                      Elite Squad           7.8
# 8        en          2007           No Country for Old Men           7.7
# 9        en          2007                      Ratatouille           7.5
# 10       en          2008                  The Dark Knight           8.2
# 11       en          2008                      Gran Torino           7.8
# 12       he          2008                Waltz with Bashir           7.8
# 13       en          2008              Slumdog Millionaire           7.6
# 14       en          2008                     Seven Pounds           7.5
# 15       en          2009             Inglourious Basterds           7.9
# 16       es          2009         The Secret in Their Eyes           7.8
# 17       en          2009                               Up           7.7
# 18       en          2009                             Moon           7.6
# 19       en          2009                             Emma           7.6
# 20       en          2010                        Inception           8.1
# 21       fr          2010                        Incendies           7.9
# 22       en          2010                   Shutter Island           7.8
# 23       en          2010                  My Name Is Khan           7.7
# 24       en          2010                      Toy Story 3           7.6
# 25       en          2011                         The Help           7.8
# 26       fa          2011                     A Separation           7.7
# 27       en          2011                          Warrior           7.7
# 28       en          2011                          Weekend           7.4
# 29       en          2011                Midnight in Paris           7.4
# 30       da          2012                         The Hunt           7.9
# 31       en          2012                 Django Unchained           7.8
# 32       en          2012  The Perks of Being a Wallflower           7.7
# 33       en          2012                 Moonrise Kingdom           7.6
# 34       en          2012            The Dark Knight Rises           7.6
# 35       en          2013          The Wolf of Wall Street           7.9
# 36       en          2013                        Prisoners           7.9
# 37       en          2013                 12 Years a Slave           7.9
# 38       en          2013               Dallas Buyers Club           7.9
# 39       en          2013                              Her           7.9
# 40       en          2014                         Whiplash           8.3
# 41       en          2014                     Interstellar           8.1
# 42       en          2014               The Imitation Game           8.0
# 43       en          2014         The Grand Budapest Hotel           8.0
# 44       en          2014                        Gone Girl           7.9
# 45       en          2015                       Inside Out           8.0
# 46       en          2015                        Spotlight           7.8
# 47       en          2015           Straight Outta Compton           7.7
# 48       en          2015                       Ex Machina           7.6
# 49       en          2015                      The Martian           7.6
# 50       en          2016                    Me Before You           7.6
# 51       en          2016                         Deadpool           7.4
# 52       ko          2016                      The Wailing           7.2
# 53       en          2016                  Eddie the Eagle           7.2
# 54       en          2016       Captain America: Civil War           7.1
#
#         country                          director
# 0           USA                 Christopher Nolan
# 1           USA                   Martin Scorsese
# 2       Germany  Florian Henckel von Donnersmarck
# 3           USA                  Gabriele Muccino
# 4           USA                    James McTeigue
# 5           USA              Paul Thomas Anderson
# 6           USA                         Sean Penn
# 7        Brazil                       Jos Padilha
# 8           USA                        Ethan Coen
# 9           USA                         Brad Bird
# 10          USA                 Christopher Nolan
# 11      Germany                    Clint Eastwood
# 12       Israel                        Ari Folman
# 13           UK                       Danny Boyle
# 14          USA                  Gabriele Muccino
# 15          USA                 Quentin Tarantino
# 16    Argentina               Juan Jos Campanella
# 17          USA                       Pete Docter
# 18           UK                      Duncan Jones
# 19           UK                   Douglas McGrath
# 20          USA                 Christopher Nolan
# 21       Canada                  Denis Villeneuve
# 22          USA                   Martin Scorsese
# 23        India                       Karan Johar
# 24          USA                       Lee Unkrich
# 25          USA                       Tate Taylor
# 26         Iran                    Asghar Farhadi
# 27          USA                    Gavin O'Connor
# 28           UK                      Andrew Haigh
# 29        Spain                       Woody Allen
# 30      Denmark                 Thomas Vinterberg
# 31          USA                 Quentin Tarantino
# 32          USA                   Stephen Chbosky
# 33          USA                      Wes Anderson
# 34           UK                 Christopher Nolan
# 35          USA                   Martin Scorsese
# 36          USA                  Denis Villeneuve
# 37          USA                     Steve McQueen
# 38          USA                   Jean-Marc Vall殄
# 39          USA                       Spike Jonze
# 40          USA                   Damien Chazelle
# 41          USA                 Christopher Nolan
# 42           UK                     Morten Tyldum
# 43          USA                      Wes Anderson
# 44          USA                     David Fincher
# 45          USA                       Pete Docter
# 46          USA                      Tom McCarthy
# 47          USA                      F. Gary Gray
# 48           UK                      Alex Garland
# 49           UK                      Ridley Scott
# 50           UK                     Thea Sharrock
# 51          USA                        Tim Miller
# 52  South Korea                       Hong-jin Na
# 53           UK                   Dexter Fletcher
# 54          USA                     Anthony Russo

# %%
# import pandas as pd
# import matplotlib.pyplot as plt

# csv_file1 = 'tmdb_5000_movies.csv'
# csv_file2 = 'movies.csv'

# df1 = pd.read_csv(csv_file1)
# df2 = pd.read_csv(csv_file2)

# df2.rename(columns={'name': 'title'}, inplace=True)
# df = pd.merge(df1, df2, on='title')
# df.drop(['budget_x','keywords','genres','homepage','original_title','rating','gross',\
#          'budget_y','spoken_languages','runtime_y','production_companies','revenue',\
#          'production_countries','tagline','released','votes','year','status','score',\
#          'popularity'], axis=1, inplace=True)
# df.rename(columns={'original_language': 'language','runtime_x': 'runtime'}, inplace=True)

# #df.set_index('title', inplace=True)
# df.dropna(inplace=True)


#     # 2006 - 2016
# df['release_date'] = df['release_date'].str.replace('-', '')
# df['release_date'] = df['release_date'].map(lambda x: int(x)//10000)
# movie_of_year = df.groupby('release_date', group_keys=False).apply(lambda x: x.sort_values('vote_average',ascending=False))\
#         .groupby('release_date').first().reset_index()
# movie_of_year.drop(['overview', 'writer', 'star', 'runtime', 'company',
#                         'genre', 'vote_count'], axis=1, inplace=True)
# movie_of_year = movie_of_year[movie_of_year.release_date>2005].reset_index()
# movie_of_year.drop(['index'], axis=1, inplace=True)
# movie_of_year.to_csv('movie_of_year.csv',index=False)

# %%
# df4 = pd.read_csv('movie_of_year.csv')
# df4.set_index('release_date', inplace=True)
# # if year not in df4.index:
# #     ptint(1)
# # else:
# #     print(2)
# #df4.dtypes
#     #
# movie=df4.loc[2003]
# movie
# #f4
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/.local/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 2003
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-39-fafea1b8acb6> in <module>
#       7 #df4.dtypes
#       8     #
# ----> 9 movie=df4.loc[2003]
#      10 movie
#      11 #f4
#
# ~/.local/lib/python3.6/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1422
#    1423             maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1424             return self._getitem_axis(maybe_callable, axis=axis)
#    1425
#    1426     def _is_scalar_access(self, key: Tuple):
#
# ~/.local/lib/python3.6/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1848         # fall thru to straight lookup
#    1849         self._validate_key(key, axis)
# -> 1850         return self._get_label(key, axis=axis)
#    1851
#    1852
#
# ~/.local/lib/python3.6/site-packages/pandas/core/indexing.py in _get_label(self, label, axis)
#     158             raise IndexingError("no slices here, handle elsewhere")
#     159
# --> 160         return self.obj._xs(label, axis=axis)
#     161
#     162     def _get_loc(self, key: int, axis: int):
#
# ~/.local/lib/python3.6/site-packages/pandas/core/generic.py in xs(self, key, axis, level, drop_level)
#    3735             loc, new_index = self.index.get_loc_level(key, drop_level=drop_level)
#    3736         else:
# -> 3737             loc = self.index.get_loc(key)
#    3738
#    3739             if isinstance(loc, np.ndarray):
#
# ~/.local/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
# -> 2899                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2900         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2901         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 2003

# %%
year_movie_df = pd.read_csv('/home/kevin/Documents/9321/github/Plan_Z/data_analysis/movie_of_year.csv')
movie = year_movie_df.to_json(orient='records')
movie = json.loads(movie)
movie
# Out:
# [{'release_date': 2006,
#   'id': 1124,
#   'language': 'en',
#   'title': 'The Prestige',
#   'vote_average': 8.0,
#   'country': 'USA',
#   'director': 'Christopher Nolan'},
#  {'release_date': 2007,
#   'id': 7345,
#   'language': 'en',
#   'title': 'There Will Be Blood',
#   'vote_average': 7.9,
#   'country': 'USA',
#   'director': 'Paul Thomas Anderson'},
#  {'release_date': 2008,
#   'id': 155,
#   'language': 'en',
#   'title': 'The Dark Knight',
#   'vote_average': 8.2,
#   'country': 'USA',
#   'director': 'Christopher Nolan'},
#  {'release_date': 2009,
#   'id': 16869,
#   'language': 'en',
#   'title': 'Inglourious Basterds',
#   'vote_average': 7.9,
#   'country': 'USA',
#   'director': 'Quentin Tarantino'},
#  {'release_date': 2010,
#   'id': 27205,
#   'language': 'en',
#   'title': 'Inception',
#   'vote_average': 8.1,
#   'country': 'USA',
#   'director': 'Christopher Nolan'},
#  {'release_date': 2011,
#   'id': 50014,
#   'language': 'en',
#   'title': 'The Help',
#   'vote_average': 7.8,
#   'country': 'USA',
#   'director': 'Tate Taylor'},
#  {'release_date': 2012,
#   'id': 103663,
#   'language': 'da',
#   'title': 'The Hunt',
#   'vote_average': 7.9,
#   'country': 'Denmark',
#   'director': 'Thomas Vinterberg'},
#  {'release_date': 2013,
#   'id': 106646,
#   'language': 'en',
#   'title': 'The Wolf of Wall Street',
#   'vote_average': 7.9,
#   'country': 'USA',
#   'director': 'Martin Scorsese'},
#  {'release_date': 2014,
#   'id': 244786,
#   'language': 'en',
#   'title': 'Whiplash',
#   'vote_average': 8.3,
#   'country': 'USA',
#   'director': 'Damien Chazelle'},
#  {'release_date': 2015,
#   'id': 150540,
#   'language': 'en',
#   'title': 'Inside Out',
#   'vote_average': 8.0,
#   'country': 'USA',
#   'director': 'Pete Docter'},
#  {'release_date': 2016,
#   'id': 296096,
#   'language': 'en',
#   'title': 'Me Before You',
#   'vote_average': 7.6,
#   'country': 'UK',
#   'director': 'Thea Sharrock'}]

# %%
csv_file1 = '/home/kevin/Documents/9321/github/Plan_Z/data_analysis/tmdb_5000_movies.csv'
csv_file2 = '/home/kevin/Documents/9321/github/Plan_Z/data_analysis/movies.csv'
year_movie_csv = '/home/kevin/Documents/9321/github/Plan_Z/data_analysis/movie_of_year.csv'
    
df1 = pd.read_csv(csv_file1)
df2 = pd.read_csv(csv_file2)
year_movie_df = pd.read_csv(year_movie_csv)
   
year_movie_df.set_index('release_date', inplace=True)

df2.rename(columns={'name': 'title'}, inplace=True)
df = pd.merge(df1, df2, on='title')
df.drop(['budget_x','keywords','genres','homepage','id','original_title','rating','gross',\
         'budget_y','spoken_languages','runtime_y','production_companies','revenue',\
         'production_countries','tagline','released','votes','year','status','score',\
         'popularity'], axis=1, inplace=True)
df.rename(columns={'original_language': 'language','runtime_x': 'runtime'}, inplace=True)
df.dropna(inplace=True)
df['release_date'] = df['release_date'].str.replace('-', '')
df['release_date'] = df['release_date'].map(lambda x: int(x)//10000)
year=[2020]
if df.release_date.isin(year):
    print(1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-26-568bd23229c2> in <module>
#      19 df['release_date'] = df['release_date'].str.replace('-', '')
#      20 df['release_date'] = df['release_date'].map(lambda x: int(x)//10000)
# ---> 21 year=list(2020)
#      22 if df.release_date.isin(year):
#      23     print(1)
#
# TypeError: 'int' object is not iterable
