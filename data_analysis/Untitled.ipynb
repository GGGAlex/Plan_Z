# %%
# import pandas as pd


# csv_file1 = 'tmdb_5000_movies.csv'
# csv_file2 = 'movies.csv'

# df1 = pd.read_csv(csv_file1)
# df2 = pd.read_csv(csv_file2)

# df2.rename(columns={'name': 'title'}, inplace=True)
# df = pd.merge(df1, df2, on='title')
# df.drop(['budget_x','keywords','genres','homepage','id','original_title','rating','gross',\
#          'budget_y','spoken_languages','runtime_y','production_companies','revenue',\
#          'production_countries','tagline','released','votes','year','status','score',\
#          'popularity'], axis=1, inplace=True)
# df.rename(columns={'original_language': 'language','runtime_x': 'runtime'}, inplace=True)
# # df.rename(columns={'original_language': 'language','runtime_x': 'runtime'}, inplace=True)

# #df.set_index('title', inplace=True)
# df.dropna(inplace=True)
# df
# Out:
#      language                                           overview release_date  \
# 0          en  In the 22nd century, a paraplegic Marine is di...   2009-12-10
# 1          en  Captain Barbossa, long believed to be dead, ha...   2007-05-19
# 2          en  A cryptic message from Bond’s past sends him o...   2015-10-26
# 3          en  Following the death of District Attorney Harve...   2012-07-16
# 4          en  John Carter is a war-weary, former military ca...   2012-03-07
# ...       ...                                                ...          ...
# 3162       en  Two business executives--one an avowed misogyn...   1997-01-19
# 3163       en  The boredom of small town life is eating Bill ...   2009-08-14
# 3164       en  Presents a day in the life in Austin, Texas am...   1990-07-27
# 3165       en  Friends/fledgling entrepreneurs invent a devic...   2004-10-08
# 3166       es  El Mariachi just wants to play his guitar and ...   1992-09-04
#
#       runtime                                     title  vote_average  \
# 0       162.0                                    Avatar           7.2
# 1       169.0  Pirates of the Caribbean: At World's End           6.9
# 2       148.0                                   Spectre           6.3
# 3       165.0                     The Dark Knight Rises           7.6
# 4       132.0                               John Carter           6.1
# ...       ...                                       ...           ...
# 3162     97.0                     In the Company of Men           6.8
# 3163     85.0                                   Rampage           6.0
# 3164     97.0                                   Slacker           6.4
# 3165     77.0                                    Primer           6.9
# 3166     81.0                               El Mariachi           6.6
#
#       vote_count                                  company country  \
# 0          11800   Twentieth Century Fox Film Corporation      UK
# 1           4500                     Walt Disney Pictures     USA
# 2           4466                                      B24      UK
# 3           9106                             Warner Bros.      UK
# 4           2124                     Walt Disney Pictures     USA
# ...          ...                                      ...     ...
# 3162          44         Alliance Atlantis Communications  Canada
# 3163         131  De Laurentiis Entertainment Group (DEG)     USA
# 3164          77                    Detour Filmproduction     USA
# 3165         658                                     ERBP     USA
# 3166         238            Columbia Pictures Corporation     USA
#
#                director   genre               star             writer
# 0         James Cameron  Action    Sam Worthington      James Cameron
# 1        Gore Verbinski  Action        Johnny Depp        Ted Elliott
# 2            Sam Mendes  Action       Daniel Craig         John Logan
# 3     Christopher Nolan  Action     Christian Bale     Jonathan Nolan
# 4        Andrew Stanton  Action      Taylor Kitsch     Andrew Stanton
# ...                 ...     ...                ...                ...
# 3162        Neil LaBute  Comedy      Aaron Eckhart        Neil LaBute
# 3163   William Friedkin   Drama      Michael Biehn    William P. Wood
# 3164  Richard Linklater  Comedy  Richard Linklater  Richard Linklater
# 3165      Shane Carruth   Drama      Shane Carruth      Shane Carruth
# 3166   Robert Rodriguez  Action    Carlos Gallardo   Robert Rodriguez
#
# [3167 rows x 13 columns]

# %%
import pandas as pd
import matplotlib.pyplot as plt

csv_file1 = 'tmdb_5000_movies.csv'
csv_file2 = 'movies.csv'

df1 = pd.read_csv(csv_file1)
df2 = pd.read_csv(csv_file2)

df2.rename(columns={'name': 'title'}, inplace=True)
df = pd.merge(df1, df2, on='title')
df.drop(['budget_x','keywords','genres','homepage','original_title','rating','gross',\
         'budget_y','spoken_languages','runtime_y','production_companies','revenue',\
         'production_countries','tagline','released','votes','year','status','score',\
         'popularity'], axis=1, inplace=True)
df.rename(columns={'original_language': 'language','runtime_x': 'runtime'}, inplace=True)

#df.set_index('title', inplace=True)
df.dropna(inplace=True)


    # 2006 - 2016
df['release_date'] = df['release_date'].str.replace('-', '')
df['release_date'] = df['release_date'].map(lambda x: int(x)//10000)
movie_of_year = df.groupby('release_date', group_keys=False).apply(lambda x: x.sort_values('vote_average',ascending=False))\
        .groupby('release_date').first().reset_index()
movie_of_year.drop(['overview', 'writer', 'star', 'runtime', 'company',
                        'genre', 'vote_count'], axis=1, inplace=True)
movie_of_year = movie_of_year[movie_of_year.release_date>2005].reset_index()
movie_of_year.drop(['index'], axis=1, inplace=True)
movie_of_year.to_csv('movie_of_year.csv',index=False)

# %%
df4 = pd.read_csv('movie_of_year.csv')
df4.set_index('release_date', inplace=True)
# if year not in df4.index:
#     ptint(1)
# else:
#     print(2)
#df4.dtypes
    #
movie=df4.loc[2006]
movie
# Out:
# id                           1124
# language                       en
# title                The Prestige
# vote_average                    8
# country                       USA
# director        Christopher Nolan
# Name: 2006, dtype: object
